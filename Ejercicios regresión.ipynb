# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
gamma = ny.array([50,70,90,110,130])
thau = ny.array([6.01,7.48,8.59,9.19,10.21])

# %% [markdown]
# #### A partir de los datos se realizará un ajuste de ecuación de potencia de la forma:
# $$\tau = \mu\gamma^n$$

# %%
plt.plot(thau,gamma,'*k',label='Datos')
plt.xlabel('$\dot\gamma$')
plt.ylabel('$\\tau$')
plt.legend()
plt.show()

# %% [markdown]
# #### Se realizará una regresión lineal para los datos anteriormente mostrados:

# %%
(a,b)= polyfit(gamma,thau,1)
print('Regresión lineal con parámetros: a=%.2f b=%.2f' % (a,b))
# Out:
# Regresión lineal con parámetros: a=0.05 b=3.75

# %%
t = np.linspace(gamma[0],gamma[-1])
modelo = polyval([a,b],t)
plt.plot(gamma,thau,'*b',label = 'Datos')
plt.plot(t,modelo,'-k', label = 'a=%.2f b=%.2f' % (a,b))
plt.legend()
