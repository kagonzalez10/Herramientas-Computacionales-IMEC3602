# %%
# %pylab inline
import os
import pandas as pd
from scipy import ndimage
from scipy.fftpack import fft,ifft
import mpmath
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['ifft', 'fft', 'axis']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Introducción al análisis frecuencial
# Es común ver que en varías aplicaciones se utilice algún tipo de análisis frecuencial para tratar las señales recibidas de algún dispositivo. Uno de los casos más frecuentes es la música, en las grabaciones de cualquier trabajo musical se requiere ecualizar bien sea un instrumento o la voz de algún cantante, a través de un ecualizador. La función de este dispositivo es filtrar la señal a grabar, para así mejorar la calidad del sonido, eliminando cierto ruido o frecuencias indeseadas. A continuación se mostrará una aproximación al análisis frecuencial de señales por medio de la transformación de Fourier.
#
# ### 1. Las funciones: FFT, IFFT, FFTSHIFT, IFFTSHIFT
# La función FFT realiza una transformación de Fourier rápida de cualquier función. Esta función puede tener diferentes aplicaciones que serán mostradas más adelante.

# %%
L=20
n=128
x2=linspace(-L/2,L/2,n+1)
x=x2[1:n+1]
u=exp(-x**2)
ut=fft(u)
utshift = fftshift(ut)
plt.figure()
plt.subplot(4,1,1)
plt.plot(x,u)
subplot(4,1,2)
plot(real(ut))
subplot(4,1,3)
plot(real(utshift))
subplot(4,1,4)
plot(abs(utshift))
plt.tight_layout()

# %% [markdown]
# **En el gráfico anterior se puede observar: (1) La función $u= e^{-x^2} $ (2) La transformación de Fourier al revés (3) La transformación de Fourier sin reversar y (4) La inversa de la transformada**
#
# ### ** 2. La transformación de Fourier Vs. Derivación con diferencias finitas **
#
# La transformación de Fourier también puede ser utilizada para hallar la derivación de alguna función por medio de la siguiente equación: $f_{tr}^{(n)} = (ik)^{n}f_{tr}$ (
# $f_{tr} $ Representa la transformación de la función $f$)

# %%
L=20
n=128
x2=linspace(-L/2,L/2,n+1)
x=x2[1:n+1]
dx = x[1]-x[0]
u=1/(cosh(x))
ut = fft(u)
k1 = np.arange(0,n/2)
k2 = np.arange(-n/2,0)
k = (2*pi/L)*np.concatenate((k1,k2), axis=0)
ut1 = np.multiply(k,ut)*1j
ut2 = -k*k*ut
u1=real(ifft(ut1))
u2=real(ifft(ut2))
u1exact =-(1/cosh(x))*tanh(x)
u2exact =(1/cosh(x))-2*(1/cosh(x))**3

ux = [0]*(n)
ux[0]=(-3*u[0]+4*u[1]-u[2])/(2*dx)

for j in range (1,n-2):
    ux[j]=(u[j+1]-u[j-1])/(2*dx)
ux[n-1]=(3*u[n-1]-4*u[n-2]+u[n-3])/(2*dx)

ux2 = [0]*(n)
ux2[0]=(-3*u[0]+4*u[1]-u[2])/(2*dx)
ux2[1]=(-3*u[1]+4*u[2]-u[3])/(2*dx)
for j in range (3,n-3):
    ux2[j]=(-u[j+2]+8*u[j+1]-8*u[j-1]+u[j-2])/(12*dx)
ux2[n-2]=(3*u[n-2]-4*u[n-3]+u[n-4])/(2*dx)
ux2[n-1]=(3*u[n-1]-4*u[n-2]+u[n-3])/(2*dx)

### PLOTTING

plt.figure()
plt.subplot(3,1,1)
plt.plot(x,u1exact,'ks-',mfc='none',markersize=4)
plt.plot(x,u1,'k',markersize=4)
plt.plot(x,ux,'ok',mfc='none',markersize=4)
plt.plot(x,ux2,'k*',markersize=4)
ax = plt.gca()
ax.set_ylim([0.47,0.5])
ax.set_xlim([-1.15,-0.75])

plt.subplot(3,1,2)
plt.plot(x,u1exact,'ks-',mfc='none',markersize=4)
plt.plot(x,u1,'vk',markersize=4)
plt.plot(x,ux,'ok',markersize=4)
plt.plot(x,ux2,'k*',markersize=4)
ax = plt.gca()
ax.set_ylim([0.49848,0.49850])
ax.set_xlim([-0.9376,-0.9374])

plt.subplot(3,1,3)
plt.plot(x,u1exact,'sk-',mfc='none',markersize=4)
plt.plot(x,u1,'kv',mfc='none',markersize=4)
plt.plot(x,ux,'ko',markersize=4)
plt.plot(x,ux2,'k*',markersize=4)
ax = plt.gca()
ax.set_ylim([0.4984871,0.4984879])
ax.set_xlim([-0.93758,-0.9374])
plt.tight_layout()

# %% [markdown]
# En la primera imagen se puede observar en que orden de magnitud se encuentra el error entre la derivación exacta y la derivación de segundo orden con diferencias finitas, el cual ronda entre los $10^{-2}$, luego en la segunda imágen se muestra la misma comparación contra la derivación de cuarto orden con diferencias finitas, con un error entre los $10^{-5}$. Finalmente, en la última imagen se ve la diferencia entre la derivación exacta y la derivación realiada a través de la transformación de Fourier.

# %%
L=20
n=128
x2=linspace(-L/2,L/2,n+1)
x=x2[1:n+1]
dx = x[1]-x[0]
u=tanh(x)
ut = fft(u)
k1 = np.arange(0,n/2)
k2 = np.arange(-n/2,0)
k = (2*pi/L)*np.concatenate((k1,k2), axis=0)
ut1 = np.multiply(k,ut)*1j
ut2 = -k*k*ut
u1=real(ifft(ut1))
u2=real(ifft(ut2))
u1exact =-(1/cosh(x))*tanh(x)
u2exact =(1/cosh(x))-2*(1/cosh(x))**3

ux = [0]*(n)
ux[0]=(-3*u[0]+4*u[1]-u[2])/(2*dx)

for j in range (1,n-2):
    ux[j]=(u[j+1]-u[j-1])/(2*dx)
ux[n-1]=(3*u[n-1]-4*u[n-2]+u[n-3])/(2*dx)

ux2 = [0]*(n)
ux2[0]=(-3*u[0]+4*u[1]-u[2])/(2*dx)
ux2[1]=(-3*u[1]+4*u[2]-u[3])/(2*dx)
for j in range (3,n-3):
    ux2[j]=(-u[j+2]+8*u[j+1]-8*u[j-1]+u[j-2])/(12*dx)
ux2[n-2]=(3*u[n-2]-4*u[n-3]+u[n-4])/(2*dx)
ux2[n-1]=(3*u[n-1]-4*u[n-2]+u[n-3])/(2*dx)

plt.plot(x,u1)
plt.plot(x,ux2,'or',markersize=2)
plt.plot(x,u)
plt.ylim(-1.5,1.5)
plt.tight_layout()

# %% [markdown]
# Nuevamente se contrasta la derivación de diferencias finitas de cuarto orden (puntos rojos) con la derivación exacta de la función $u=tanh(x)$, en contraste la derivación con la transformación de Fourier oscila fuertemente, lo que la hace inexacta para este ejercicio.
#
# ### ** 3. Aplicación de la transformación de Fourier: Detección de radar y filtros **
# En los radares de los aviones o en una estación de telecomunicaciones se enfrentan al problema de recibir señales con ruido que las hacen imposibles de analizar en una primera aproximación. Es por ello que estas señales deben ser tratadas por medio de filtros y demás procedimientos para poder obtener información de las mismas.

# %%
#L=30; % time slot to transform
#n=512; % number of Fourier modes 2^9
#t2=linspace(-L,L,n+1); t=t2(1:n); % time discretization
#k=(2*pi/(2*L))*[0:(n/2-1) -n/2:-1]; % frequency components of FFT
#u=sech(t); % ideal signal in the time domain
#figure(1), subplot(3,1,1), plot(t,u,’k’), hold on
#noise=1;
#ut=fft(u);
#utn=ut+noise*(randn(1,n)+i*randn(1,n));
#un=ifft(utn);
#figure(1), subplot(3,1,2), plot(t,abs(un),’k’), hold on

L=30
n=512
t2= linspace(-L,L,n+1)
t=t2[1:n+1]
k1 = np.arange(0,n/2)
k2 = np.arange(-n/2,0)
k = (2*pi/(2*L))*np.concatenate((k1,k2), axis=0)
u=1/(cosh(t))
plt.figure()
plt.subplot(3,1,1)
plt.plot(t,u,'k')
ax = plt.gca()
ax.set_ylim([0,1.5])
ax.set_xlim([-10,10])

noise = 1
ut= fft(u)
utn = ut+noise*(randn(n)+randn(n)*1j)
un = ifft(utn)
plt.subplot(3,1,2)
plt.plot(t,abs(un),'k')
ax = plt.gca()
ax.set_ylim([0,1.5])
ax.set_xlim([-10,10])

noise = 3
ut= fft(u)
unt = ut+noise*(randn(n)+randn(n)*1j)
un = ifft(unt)
plt.subplot(3,1,3)
plt.plot(t,abs(un),'k')
ax = plt.gca()
ax.set_ylim([0,1.5])
ax.set_xlim([-10,10])
plt.tight_layout()

# %% [markdown]
# En la figura se tiene un pulso ideal al cual se le aplicó dos diferentes niveles de intensidad de ruido "blanco" (1 y 3) el cual se encuentra presente en la mayoría de señales recibidas en un radar.

# %%
noise = 10
ut= fft(u)
unt = ut+noise*(randn(n)+randn(n)*1j)
un = ifft(unt)
plt.figure()
plt.subplot(2,1,1)
plt.plot(t,abs(un),'k')
plt.xlabel('Time(t)')
axis = plt.gca()
axis.set_ylim([0,1.5])
axis.set_xlim([-30,30])

plt.subplot(2,1,2)
plot(fftshift(k),abs(fftshift(unt))/(max(abs(fftshift(unt)))),'k')
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([-25,25])
plt.xlabel('Wavenumber(k)')
plt.tight_layout()

# %% [markdown]
# Se tiene la misma señal mostrada en la figura anterior tanto en el dominio de tiempo como en el dominio de frecuencia.

# %%
noise = 10
ut= fft(u)
unt = ut+noise*(randn(n)+randn(n)*1j)
filter = exp(-0.2*k**2)
unft = filter*unt
unf = ifft(unft)
plt.figure()
plt.subplot(3,1,1)
plt.plot(fftshift(k),abs(unt)/max(abs(unt)))
plt.plot(fftshift(k),abs(fftshift(filter)))
plt.xlabel('Wavenumber(k)')
axis = plt.gca()
axis.set_ylim([0,1])
axis.set_xlim([-25,25])

plt.subplot(3,1,2)
plt.plot(fftshift(k),abs(fftshift(unft))/(max(abs(fftshift(unft)))))
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([-25,25])
plt.xlabel('Wavenumber(k)')

plt.subplot(3,1,3)
plt.plot(t,unf)
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([-25,25])
plt.xlabel('Time(t)')
plt.tight_layout()
# Out:
# /anaconda3/lib/python3.6/site-packages/numpy/core/numeric.py:531: ComplexWarning: Casting complex values to real discards the imaginary part
#   return array(a, dtype, copy=False, order=order)

# %% [markdown]
# En la primera figura se muestra la señal inundada de ruido "blanco" a lo largo del espectro de frecuencias. En la segunda figura se le aplica un filtro Gaussiano ($F(k)=e^{-\tau(k-k_o)^2}$) con $\tau = 0.2$ y $k_o =0$ y por último, en la tercera figura se reconstruye la señal en el tiempo y se puede apreciar que la señal es más limpia.

# %%
filter=exp(-0.2*(k-15)**2);
unft=filter*unt;
unf=ifft(unft);
plt.figure()
plt.subplot(3,1,1)
plt.plot(fftshift(k),abs(unt)/max(abs(unt)))
plt.plot(fftshift(k),abs(fftshift(filter)))
plt.xlabel('Wavenumber(k)')
axis = plt.gca()
axis.set_ylim([0,1])
axis.set_xlim([-25,25])

plt.subplot(3,1,2)
plt.plot(fftshift(k),abs(fftshift(unft))/(max(abs(fftshift(unft)))))
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([-25,25])
plt.xlabel('Wavenumber(k)')

plt.subplot(3,1,3)
plt.plot(t,abs(unf))
ax = plt.gca()
ax.set_ylim([0,1])
ax.set_xlim([-25,25])
plt.xlabel('Time(t)')
plt.tight_layout()

# %% [markdown]
# Ahora la misma señal se filtra con un parámetro de ancho de banda de $\tau = 0.2 $ centrado en la frecuencia $k_o=15$
#
# ### ** 4. Aplicación de la transformación de Fourier: Detección de radar y promedio **

# %%
L=30
n=512
t2=linspace(-L,L,n+1)
t=t2[1:n+1]
k1 = np.arange(0,n/2)
k2 = np.arange(-n/2,0)
k = (2*pi/L)*np.concatenate((k1,k2), axis=0)
ks=fftshift(k)
noise=10
realize=[1,2,5,100]
u=1/(cosh(t))
ave=[0]*n
ut=fft(u)
utn = []
dat = []
un = []
for jj in range(0,4):
    for j in range (0,realize[jj]):
        utn.append(np.array(ut+noise*(randn(n)+complex(1,0)*randn(n))))
        ave = ave+utn[j]
        dat.append(abs(fftshift(utn[j]))/max(abs(utn[j])))
        un[j:]=ifft(utn[j:])
    ave = abs(fftshift(ave))/realize[jj]
    plt.figure()
    subplot(4,1,jj+1)
    plt.plot(ks,ave/max(ave),'k')

# %% [markdown]
# Se tomó la misma señal con ruido mencionada anteriormente y se realizo un promedio con diferentes realizaciones. Para la primera figura (1 realización) no es claro si lo registrado es una señal o solo es ruido. En la segunda figura (2 realizaciones) se reduce el ruido pero aún no se esclarece la información, para la tercera (5 realizaciones) ya se puede percibir una señal destacada y finalmente en la cuarta figura (100 realizaciones) es clara la señal y no contiene mayor ruido en ella.

# %%
#dat(j,:)=abs(fftshift(utn(j,:)))/max(abs(utn(j,:)));
#un(j,:)=ifft(utn(j,:));
#end
#ave=abs(fftshift(ave))/realize(jj);
#subplot(4,1,jj)
#plot(ks,ave/max(ave),’k’)
#set(gca,’Fontsize’,[15])
#axis([-20 20 0 1])
#text(-18,0.7,labels(jj,:),’Fontsize’,[15])
#ylabel(’|fft(u)|’,’Fontsize’,[15])
#end
#hold on
#plot(ks,abs(fftshift(ut))/max(abs(ut)),’k:’,’Linewidth’,[2])
#set(gca,’Fontsize’,[15])
#xlabel(’frequency (k)’)
